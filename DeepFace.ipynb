# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import deepface library
from deepface import DeepFace
# Out:
# Directory  C:\Users\janit /.deepface created
# Directory  C:\Users\janit /.deepface/weights created

# %%
img = cv2.imread('testdata/happygirl.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# <h2> Making Predictions using deep face library

# %%
predictions = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\janit\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:03<00:00, 1.75MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\janit\.deepface\weights\age_model_weights.h5
#  97%|████████████████████████████████████████████████████████████████████████████████████▍  | 523M/539M [04:48<00:08, 1.92MB/s]

# %%
# This is a dictionary
predictions

# %%
predictions['dominant_emotion']

# %%
# To identify faces and to draw a rectangle
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
